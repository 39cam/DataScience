# %%
import re

import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk

# %%
# https://www.kaggle.com/datasets/arushchillar/disneyland-reviews
df = pd.read_csv('DisneylandReviews.csv')

# %%
df
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
# [42656 rows x 6 columns]

# %% [markdown]
# ### Entender el dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          42656 non-null  int64
#  1   Rating             42656 non-null  int64
#  2   Year_Month         42656 non-null  object
#  3   Reviewer_Location  42656 non-null  object
#  4   Review_Text        42656 non-null  object
#  5   Branch             42656 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.3+ MB

# %%
# mostrar filas de 100 a 200
df.iloc[100:201, :]
# Out:
#      Review_ID  Rating Year_Month     Reviewer_Location  \
# 100  662664830       3     2019-2                 India
# 101  662641193       1     2019-3                 India
# 102  662600452       4     2019-3             Singapore
# 103  662592140       4     2019-4         United States
# 104  662516931       5     2019-3             Australia
# ..         ...     ...        ...                   ...
# 196  653828557       4    2018-12             Hong Kong
# 197  653746393       5     2018-3  United Arab Emirates
# 198  653600635       5     2018-5             Indonesia
# 199  653600185       4     2018-6             Hong Kong
# 200  653385350       5     2019-2         United States
#
#                                            Review_Text               Branch
# 100  It   s a very huge game cum theme park, so if ...  Disneyland_HongKong
# 101  The main attractions were shut while we still ...  Disneyland_HongKong
# 102  While it's not as great other Disney propertie...  Disneyland_HongKong
# 103  We made it to Honk Kong Disney on the MTR and ...  Disneyland_HongKong
# 104  Even though it is smaller, there is great ride...  Disneyland_HongKong
# ..                                                 ...                  ...
# 196  Such a lovely place that really took me back t...  Disneyland_HongKong
# 197  Fantastic experience. Enjoyed every step of ou...  Disneyland_HongKong
# 198  No doubt people keep saying this is the happie...  Disneyland_HongKong
# 199  We never had went Tokyo Disneyland or Shanghai...  Disneyland_HongKong
# 200  Much smaller than the US versions and you can ...  Disneyland_HongKong
#
# [101 rows x 6 columns]

# %%
## ¿Hay comentarios largos?

def calculate_words(fila):
    word = fila["Review_Text"]
    return len(word.split(" "))

df["words_count"] = df.apply(calculate_words, axis=1)

# %%
df.describe()
# Out:
#           Review_ID        Rating   words_count
# count  4.265600e+04  42656.000000  42656.000000
# mean   3.188553e+08      4.217695    132.174723
# std    1.657092e+08      1.063371    160.717790
# min    1.398724e+06      1.000000      4.000000
# 25%    1.743274e+08      4.000000     46.000000
# 50%    2.907583e+08      5.000000     82.000000
# 75%    4.489579e+08      5.000000    158.000000
# max    6.708014e+08      5.000000   5600.000000

# %%
df[df["words_count"] < 5]
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location         Review_Text  \
# 29981  606997669       5     2018-8            France  ActiveX VT ERROR:
# 32592  457253942       5     2016-5      Saudi Arabia  ActiveX VT ERROR:
#
#                  Branch  words_count
# 29981  Disneyland_Paris            4
# 32592  Disneyland_Paris            4

# %% [markdown]
# ## palabras que se repiten

# %%
texto_completo = ' '.join(review for review in df['Review_Text'])

# %%
stopwords = set(STOPWORDS)
stopwords.update(["de", "la", "que", "el", "en", "y", "a", "los", "del", "las", "un", "por", "no", "una", "su", "para", "es", "al", "lo", "como", "más", "pero", "sus", "le", "ya", "o", "este", "ha", "sí", "porque", "esta", "cuando", "muy", "sin", "sobre", "también", "me", "hasta", "hay", "donde", "quien", "desde", "todo", "nos", "durante", "todos", "uno", "les", "ni", "contra", "otros", "ese", "eso", "ante", "ellos", "e", "esto", "mí", "antes", "algunos", "qué", "ninguno", "mi", "mis", "tú", "te", "ti", "tu", "tus", "ellas", "nosotros", "vosotros", "vosotras", "os", "mío", "mía", "míos", "mías", "tuyo", "tuya"])

wordcloud = WordCloud(stopwords=stopwords,
                      background_color="white",
                      max_words=100,
                      width=800,
                      height=400).generate(texto_completo)

print("\nGenerando la nube de palabras...")
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# Generando la nube de palabras...

# %% [markdown]
# ### Preprocesamiento

# %% [markdown]
# 0. quitar ruido identificado

# %%
df["Review_Text"]
# Out:
# 0        If you've ever been to Disneyland anywhere you...
# 1        Its been a while since d last time we visit HK...
# 2        Thanks God it wasn   t too hot or too humid wh...
# 3        HK Disneyland is a great compact park. Unfortu...
# 4        the location is not in the city, took around 1...
#                                ...
# 42651    i went to disneyland paris in july 03 and thou...
# 42652    2 adults and 1 child of 11 visited Disneyland ...
# 42653    My eleven year old daughter and myself went to...
# 42654    This hotel, part of the Disneyland Paris compl...
# 42655    I went to the Disneyparis resort, in 1996, wit...
# Name: Review_Text, Length: 42656, dtype: object

# %%
## remover espacio en "wasn   t"
df['Review_Text'] = df['Review_Text'].str.replace(r'wasn\s+t', "wasn't", regex=True)

# %%
df["Review_Text"]
# Out:
# 0        If you've ever been to Disneyland anywhere you...
# 1        Its been a while since d last time we visit HK...
# 2        Thanks God it wasn't too hot or too humid when...
# 3        HK Disneyland is a great compact park. Unfortu...
# 4        the location is not in the city, took around 1...
#                                ...
# 42651    i went to disneyland paris in july 03 and thou...
# 42652    2 adults and 1 child of 11 visited Disneyland ...
# 42653    My eleven year old daughter and myself went to...
# 42654    This hotel, part of the Disneyland Paris compl...
# 42655    I went to the Disneyparis resort, in 1996, wit...
# Name: Review_Text, Length: 42656, dtype: object

# %% [markdown]
# 1. minúsculas

# %%
df["processed_text"] = df["Review_Text"].str.lower()

# %%
df["processed_text"]
# Out:
# 0        if you've ever been to disneyland anywhere you...
# 1        its been a while since d last time we visit hk...
# 2        thanks god it wasn't too hot or too humid when...
# 3        hk disneyland is a great compact park. unfortu...
# 4        the location is not in the city, took around 1...
#                                ...
# 42651    i went to disneyland paris in july 03 and thou...
# 42652    2 adults and 1 child of 11 visited disneyland ...
# 42653    my eleven year old daughter and myself went to...
# 42654    this hotel, part of the disneyland paris compl...
# 42655    i went to the disneyparis resort, in 1996, wit...
# Name: processed_text, Length: 42656, dtype: object

# %% [markdown]
# 2. remover caracteres especiales

# %%
def remove_especial_text(row):
    # Eliminar números (enteros y decimales)
    row = re.sub(r'\d+', '', row)
    
    # Eliminar caracteres especiales (puntuación, símbolos, etc.)
    row = re.sub(r'[^\w\s]', '', row)
    
    # Eliminar espacios extra y limpiar al inicio y final
    row = ' '.join(row.split())
    
    return row

df["processed_text"] = df["processed_text"].apply(remove_especial_text)

# %%
df["processed_text"]
# Out:
# 0        if youve ever been to disneyland anywhere youl...
# 1        its been a while since d last time we visit hk...
# 2        thanks god it wasn t too hot or too humid when...
# 3        hk disneyland is a great compact park unfortun...
# 4        the location is not in the city took around ho...
#                                ...
# 42651    i went to disneyland paris in july and thought...
# 42652    adults and child of visited disneyland paris b...
# 42653    my eleven year old daughter and myself went to...
# 42654    this hotel part of the disneyland paris comple...
# 42655    i went to the disneyparis resort in with a sma...
# Name: processed_text, Length: 42656, dtype: object

# %%
# valores con espacios
df_espacios = df[df["processed_text"].str.replace(r'\s+', '', regex=True) == '']
df_espacios
# Out:
# Empty DataFrame
# Columns: [Review_ID, Rating, Year_Month, Reviewer_Location, Review_Text, Branch, words_count, processed_text, tokenization]
# Index: []

# %% [markdown]
# 3. initial tokenization

# %%
df["tokenization"] = df["processed_text"].str.split(" ")

# %%
df["tokenization"]
# Out:
# 0        [if, you've, ever, been, to, disneyland, anywh...
# 1        [its, been, a, while, since, d, last, time, we...
# 2        [thanks, god, it, wasn't, too, hot, or, too, h...
# 3        [hk, disneyland, is, a, great, compact, park, ...
# 4        [the, location, is, not, in, the, city, took, ...
#                                ...
# 42651    [i, went, to, disneyland, paris, in, july, 03,...
# 42652    [2, adults, and, 1, child, of, 11, visited, di...
# 42653    [my, eleven, year, old, daughter, and, myself,...
# 42654    [this, hotel, part, of, the, disneyland, paris...
# 42655    [i, went, to, the, disneyparis, resort, in, 19...
# Name: tokenization, Length: 42656, dtype: object

# %% [markdown]
# 4. stop words

# %%
def remove_stopwords(words):
    filtered_words = [word for word in words if word not in STOPWORDS]
    
    return filtered_words

df['tokenization'] = df['tokenization'].apply(remove_stopwords)

# %%
df['tokenization']
# Out:
# 0        [disneyland, anywhere, find, disneyland, hong,...
# 1        [d, last, time, visit, hk, disneyland, , yet, ...
# 2        [thanks, god, hot, humid, visiting, park, , , ...
# 3        [hk, disneyland, great, compact, park, unfortu...
# 4        [location, city, took, around, 1, hour, kowlon...
#                                ...
# 42651    [went, disneyland, paris, july, 03, thought, b...
# 42652    [2, adults, 1, child, 11, visited, disneyland,...
# 42653    [eleven, year, old, daughter, went, visit, son...
# 42654    [hotel, part, disneyland, paris, complex, wond...
# 42655    [went, disneyparis, resort, 1996, small, child...
# Name: tokenization, Length: 42656, dtype: object

# %% [markdown]
# 5. revisión final

# %%
df_vacias = df[df['tokenization'].apply(len) == 0]

print("Filas con listas de tokens vacías:")
print(df_vacias)
# Out:
# Filas con listas de tokens vacías:
# Empty DataFrame
# Columns: [Review_ID, Rating, Year_Month, Reviewer_Location, Review_Text, Branch, words_count, processed_text, tokenization]
# Index: []

# %% [markdown]
# 6. TF-IDF

# %%
vectorizer = TfidfVectorizer(
    stop_words='english'
)
tfidf_matrix  = vectorizer.fit_transform(df['processed_text'])

# %%
vectorizer.get_feature_names_out()[0:1000]
# Out:
# array(['aa', 'aaa', 'aaaaaand', 'aaaages', 'aaahhh', 'aaahs',
#        'aaamembers', 'aaarrr', 'aaat', 'aack', 'aagh', 'aah', 'aahing',
#        'aahs', 'aamerican', 'aana', 'aarohi', 'aart', 'aat',
#        'aatractions', 'aaw', 'aazing', 'ab', 'aback', 'abandon',
#        'abandoned', 'abandoning', 'abandonment', 'abated', 'abatesadd',
#        'abb', 'abbey', 'abbreviated', 'abbupt', 'abc', 'abcs', 'abd',
#        'abdomen', 'abdominal', 'abe', 'abel', 'aberdeen', 'abet', 'abhor',
#        'abhorrence', 'abhorrent', 'abide', 'abiding', 'abilities',
#        'ability', 'abilitythis', 'abit', 'ablaze', 'able', 'abled',
#        'ableist', 'ablemore', 'abler', 'ablue', 'ablution', 'ablutions',
#        'abnormal', 'abnormally', 'aboad', 'aboard', 'abolish',
#        'abolishing', 'abolutely', 'abominable', 'abomination',
#        'aborigines', 'abot', 'abou', 'aboud', 'aboufour', 'abound',
#        'abounds', 'abour', 'aboustley', 'abousuluty', 'aboutafter',
#        'aboutand', 'aboutbut', 'aboutcom', 'aboutdidnt', 'aboutdisney',
#        'aboutfor', 'abouth', 'abouthighlight', 'abouti', 'aboutif',
#        'aboutit', 'aboutjedi', 'aboutmore', 'aboutmy', 'aboutnot',
#        'aboutnow', 'aboutonly', 'aboutoverall', 'aboutprince',
#        'aboutrestaurants', 'abouts', 'aboutstrangely', 'aboutthe',
#        'abouttoilets', 'abouttransport', 'abouttwo', 'aboutveg',
#        'aboutwe', 'aboutwould', 'aboutyou', 'aboveand', 'aboveanother',
#        'abovebusy', 'abovedisappointed', 'abovegood', 'aboveif',
#        'aboveinsane', 'abovenot', 'abovethe', 'abovetired', 'abovevery',
#        'abraham', 'abrasive', 'abre', 'abreast', 'abridged', 'abroad',
#        'abroadi', 'abroadnow', 'abrubt', 'abrupt', 'abruptly', 'abs',
#        'absalutley', 'absence', 'absense', 'absent', 'absentees',
#        'absiolutely', 'abso', 'absoilute', 'absoloute', 'absoloutely',
#        'absoloutly', 'absoluetly', 'absolulelty', 'absolut', 'absolute',
#        'absoluteley', 'absolutely', 'absolutelyand', 'absolutelyi',
#        'absolutelythe', 'absolutetly', 'absolutey', 'absolutle',
#        'absolutlely', 'absolutley', 'absolutly', 'absoluty', 'absorb',
#        'absorbed', 'absorbent', 'absorbing', 'absorbs', 'absorbtion',
#        'absouelty', 'absoultly', 'absoulty', 'absoulute', 'abstained',
#        'absuletly', 'absurd', 'absurdget', 'absurdly', 'abt', 'abtl',
#        'abu', 'abudhai', 'abulation', 'abundance', 'abundancestill',
#        'abundancethe', 'abundant', 'abundantly', 'abuse', 'abused',
#        'abusedso', 'abusers', 'abusing', 'abusive', 'abusiveit', 'abut',
#        'abysmal', 'abysmalif', 'abysmally', 'abything', 'ac', 'acadamy',
#        'academic', 'academy', 'academyand', 'acapella', 'acapulco',
#        'acarte', 'acccordingly', 'acceased', 'accelerating',
#        'acceleration', 'accelerator', 'accent', 'accenting', 'accents',
#        'accept', 'acceptable', 'acceptablearmed', 'acceptablei',
#        'acceptableit', 'acceptablenext', 'acceptableour',
#        'acceptableover', 'acceptableoverall', 'acceptablethe',
#        'acceptablethis', 'acceptably', 'acceptance', 'accepted',
#        'acceptedthe', 'acceptedyour', 'accepting', 'accepts', 'acceptthe',
#        'acces', 'accesibilty', 'accesible', 'access', 'accessability',
#        'accessable', 'accessble', 'accessed', 'accesses', 'accessexcept',
#        'accessexpect', 'accessfinal', 'accessi', 'accessibility',
#        'accessible', 'accessibledefinitely', 'accessibledownside',
#        'accessiblethere', 'accessiblity', 'accessibly', 'accessin',
#        'accessing', 'accessmy', 'accessoires', 'accessories',
#        'accessorieswalt', 'accessory', 'accessother', 'accessstill',
#        'accessthat', 'accessthe', 'accessyes', 'accident', 'accidental',
#        'accidentally', 'accidentfood', 'accidently', 'accidents',
#        'accidentsmake', 'accidentstar', 'accissible', 'acclaimed',
#        'acclimate', 'acclimation', 'acclimatized', 'accolade',
#        'accolades', 'accom', 'accomadate', 'accomadating', 'accomadation',
#        'accomdate', 'accomedation', 'accomidate', 'accomidates',
#        'accomidating', 'accommadated', 'accommadating', 'accommodate',
#        'accommodated', 'accommodates', 'accommodating',
#        'accommodatingeven', 'accommodatingyou', 'accommodation',
#        'accommodationbut', 'accommodationofcourse', 'accommodations',
#        'accommodationwe', 'accommodationwith', 'accommodationyou',
#        'accomodate', 'accomodated', 'accomodates', 'accomodating',
#        'accomodatingfavourite', 'accomodation', 'accomodations',
#        'accomodationsdisneyland', 'accomodationwas', 'accomodationwe',
#        'accomolished', 'accomondation', 'accompained', 'accompaned',
#        'accompanied', 'accompanies', 'accompaniment', 'accompany',
#        'accompanying', 'accomplish', 'accomplished', 'accomplishedhe',
#        'accomplishes', 'accomplishing', 'accomplishment', 'accordance',
#        'according', 'accordingly', 'accordinglyall', 'accordinglyalso',
#        'accordinglybecause', 'accordinglyboth', 'accordinglybring',
#        'accordinglybut', 'accordinglydhk', 'accordinglydo',
#        'accordinglydont', 'accordinglydrawback', 'accordinglyhope',
#        'accordinglyi', 'accordinglyif', 'accordinglymy',
#        'accordinglyonly', 'accordinglypacing', 'accordinglyread',
#        'accordinglysecond', 'accordinglysome', 'accordinglythe',
#        'accordinglythere', 'accordinglythis', 'accordinglyusually',
#        'accordinglywe', 'accordinglywell', 'accordion', 'accoridng',
#        'accosted', 'accosting', 'account', 'accountability',
#        'accountable', 'accountant', 'accountants', 'accounted',
#        'accountedwe', 'accounting', 'accounts', 'accross', 'accrue',
#        'accrued', 'acctually', 'accually', 'accuitly', 'accumulate',
#        'accumulating', 'accumulation', 'accuracy', 'accurate',
#        'accuratefor', 'accurately', 'accurateon', 'accuratethe',
#        'accuratethere', 'accuratetheres', 'accurateuse', 'accusational',
#        'accuse', 'accused', 'accusing', 'accustom', 'accustomed', 'ace',
#        'aced', 'acepted', 'acerage', 'acess', 'acessable', 'acessible',
#        'acesss', 'ache', 'ached', 'acheived', 'aches', 'achewe',
#        'achievable', 'achieve', 'achieved', 'achieveda', 'achievement',
#        'achievementi', 'achievements', 'achieves', 'achieving', 'achiles',
#        'aching', 'achingly', 'achy', 'acid', 'acidic', 'ack',
#        'acknowledge', 'acknowledged', 'acknowledgement', 'acknowledges',
#        'acknowledging', 'acknowledgment', 'acknowlege',
#        'acknowlegedement', 'ackward', 'acoffe', 'acount', 'acoup',
#        'acouple', 'acoupon', 'acoustics', 'acquaint', 'acquaintance',
#        'acquainted', 'acquiescing', 'acquire', 'acquired', 'acquires',
#        'acquiring', 'acquisition', 'acquisitions', 'acquisitive', 'acre',
#        'acreage', 'acres', 'acrobatic', 'acrobatics', 'acrobaticsthen',
#        'acrobaticswe', 'acrobats', 'acronym', 'acs', 'acsses', 'act',
#        'actaually', 'acted', 'acting', 'action', 'actionbut', 'actionget',
#        'actiongrosso', 'actionif', 'actionour', 'actions', 'actionstake',
#        'actiontemporary', 'actionthe', 'actionthough', 'actionwe',
#        'actitivies', 'activate', 'activated', 'activateswe', 'active',
#        'actively', 'activex', 'activites', 'activiteshence', 'activities',
#        'activitiesa', 'activitiesbest', 'activitiesbottom',
#        'activitiesdidnt', 'activitieseverywhere', 'activitiesi',
#        'activitiesin', 'activitiesm', 'activitiesmy', 'activitiesnever',
#        'activitiesplenty', 'activitiesthe', 'activitiesto',
#        'activitiestry', 'activitiesversus', 'activitieswaiting',
#        'activitiies', 'activity', 'activitydisney', 'activitygrizzly',
#        'activityits', 'activitynoticeble', 'activityso', 'activitythe',
#        'activty', 'actor', 'actors', 'actorsfor', 'actraction',
#        'actractions', 'actress', 'actresses', 'acts',
#        'actsbeatboxersdubstep', 'actual', 'actuality', 'actuallly',
#        'actually', 'actuallyall', 'actuallycwas', 'actuallydont',
#        'actuallyi', 'actuallypacked', 'actuallyplease', 'actuallyspace',
#        'actuallythen', 'actualy', 'actuel', 'actulaay', 'actully',
#        'actuyally', 'acurately', 'acutally', 'acutely', 'ad', 'ada',
#        'adage', 'adagio', 'adaily', 'adam', 'adamant', 'adamantly',
#        'adapt', 'adaptation', 'adaptations', 'adapted', 'adaptedthis',
#        'adapter', 'adapters', 'adaption', 'adaptor', 'adaptors',
#        'adaquate', 'aday', 'adc', 'add', 'addatives', 'added',
#        'addedgrizzle', 'addedreally', 'addedthe', 'addendumas', 'addict',
#        'addicted', 'addicting', 'addiction', 'addictions', 'addictive',
#        'addictivethere', 'addicts', 'addictsthe', 'addie', 'adding',
#        'addional', 'addition', 'additional', 'additionally',
#        'additiondisneyland', 'additions', 'additionskids', 'additionthe',
#        'additionthen', 'additionthis', 'additives', 'additonal', 'addl',
#        'addmision', 'addmission', 'addnl', 'addrenaline', 'addresed',
#        'address', 'addressed', 'addressedflorida', 'addressedin',
#        'addressednormal', 'addressedvalue', 'addresses', 'addressing',
#        'addressingthings', 'addressspace', 'addressyou', 'adds',
#        'addsverry', 'addtion', 'addvertising', 'ade', 'adeline',
#        'adentureland', 'adept', 'adeqaute', 'adequate', 'adequateeven',
#        'adequately', 'adequateshe', 'adequatethe', 'adequete', 'adequte',
#        'adeventure', 'adeventureland', 'adevnture', 'adevtnerous',
#        'adfitions', 'adhd', 'adhere', 'adhered', 'adherence', 'adheres',
#        'adhoc', 'adidas', 'adieuwould', 'adivse', 'adjacent', 'adjective',
#        'adjectives', 'adjoining', 'adjoring', 'adjust', 'adjusted',
#        'adjusting', 'adjustment', 'adjustments', 'adlabs', 'admin',
#        'administration', 'administrative', 'administrators',
#        'adminitrative', 'admirable', 'admiral', 'admirality', 'admirals',
#        'admiralss', 'admiralty', 'admiration', 'admire', 'admired',
#        'admirers', 'admiring', 'admission', 'admissioncheck',
#        'admissioneven', 'admissionfood', 'admissionfronteirlandphantom',
#        'admissions', 'admissionshe', 'admissionswe', 'admissionthis',
#        'admissionwe', 'admistson', 'admit', 'admitance', 'admitbut',
#        'admitedly', 'admitmen', 'admits', 'admittance', 'admitted',
#        'admittedbesides', 'admittedly', 'admitting', 'admitwe',
#        'admonish', 'admonished', 'admusement', 'adn', 'adolescence',
#        'adolescent', 'adolescents', 'adopt', 'adopted', 'adoptees',
#        'adopting', 'adoption', 'adorabe', 'adorable', 'adorablecons',
#        'adorablethere', 'adorablewanna', 'adoration', 'adore', 'adored',
#        'adoredthe', 'adores', 'adoring', 'adorn', 'adorned', 'adorning',
#        'adr', 'adrenal', 'adrenalin', 'adrenaline',
#        'adrenalinedisadvantages', 'adreneline', 'adress', 'adressable',
#        'adressing', 'adrift', 'adrs', 'ads', 'adukts', 'adulation',
#        'adult', 'adultall', 'adultdisney', 'adultdisneyland', 'adulte',
#        'adultfor', 'adulthood', 'adulthoodi', 'adultif', 'adultish',
#        'adultits', 'adultiwould', 'adultmagical', 'adultother', 'adults',
#        'adultsa', 'adultsall', 'adultsas', 'adultsat', 'adultsbesides',
#        'adultscustomers', 'adultsdisneyland', 'adultsfantasyland',
#        'adultsfinal', 'adultsfood', 'adultsfor', 'adultshaunted',
#        'adultshave', 'adultshowever', 'adultsi', 'adultsif', 'adultsit',
#        'adultsleaflets', 'adultsloved', 'adultsmad', 'adultsmickey',
#        'adultsmost', 'adultsof', 'adultsone', 'adultsover',
#        'adultsoverall', 'adultsparade', 'adultspetty', 'adultsright',
#        'adultssuch', 'adultsthe', 'adultsthere', 'adultstheres',
#        'adultsthey', 'adultsthis', 'adultsto', 'adultstruely',
#        'adultswarning', 'adultswas', 'adultswe', 'adultsweet',
#        'adultswish', 'adultsyou', 'adultthe', 'adulttravelling',
#        'adultwe', 'adultwhat', 'adultwhen', 'adulty', 'aduslts', 'adutls',
#        'adv', 'advailable', 'advance', 'advancealthough', 'advanceas',
#        'advancebe', 'advancebecause', 'advancebefore', 'advancebook',
#        'advancecheck', 'advanced', 'advancefast', 'advancegreat',
#        'advancei', 'advanceif', 'advanceits', 'advancelike',
#        'advancemake', 'advancement', 'advanceoverall', 'advanceparades',
#        'advancepark', 'advanceplan', 'advancereserve', 'advances',
#        'advancetake', 'advancethe', 'advancetip', 'advancetry',
#        'advanceunlike', 'advanceupto', 'advanceuse', 'advanceusual',
#        'advancewe', 'advancewhilst', 'advantage', 'advantaged',
#        'advantagefood', 'advantageous', 'advantages', 'advantagethe',
#        'advantagewe', 'advantags', 'advantge', 'advanture',
#        'advanturland', 'advanturous', 'advanwage', 'advbut', 'advcanced',
#        'adven', 'advent', 'adventerous', 'adventeure', 'adventure',
#        'adventurea', 'adventureanother', 'adventureas', 'adventurebeds',
#        'adventurebut', 'adventureca', 'adventurecastle', 'adventurecheck',
#        'adventured', 'adventuredisneyland', 'adventuredo',
#        'adventureeven', 'adventureeverything', 'adventurefantasmic',
#        'adventurefood', 'adventuregood', 'adventurehaunted',
#        'adventurehollywood', 'adventurehtml', 'adventurei', 'adventureif',
#        'adventureit', 'adventureits', 'adventureland',
#        'adventurelandadventurelandindiana', 'adventurelandalso',
#        'adventurelandattractions', 'adventurelanddole',
#        'adventurelandfantastic', 'adventurelandfun', 'adventurelandi',
#        'adventurelandits', 'adventurelandmain', 'adventurelandnice',
#        'adventurelandone', 'adventurelandonly', 'adventurelandphilors',
#        'adventurelands', 'adventurelandthe', 'adventurelandthis',
#        'adventurelandwe', 'adventurelandwhere', 'adventurelove',
#        'adventuremagic', 'adventuremet', 'adventuremost', 'adventuremy',
#        'adventurenothing', 'adventureone', 'adventureour', 'adventureous',
#        'adventurepinocchios', 'adventurepirates', 'adventurepros',
#        'adventurer', 'adventureracerind', 'adventureralways',
#        'adventurerc', 'adventurers', 'adventures', 'adventuresbut',
#        'adventureseparate', 'adventureshiglights', 'adventureshopsquite',
#        'adventureshours', 'adventuresi', 'adventuresome',
#        'adventurespace', 'adventureswe', 'adventuretarzans',
#        'adventurethat', 'adventurethe', 'adventurethen', 'adventurethere',
#        'adventurethey', 'adventurethis', 'adventurethough',
#        'adventuretwo', 'adventurevegetarian', 'adventurevery',
#        'adventurewait', 'adventurewe', 'adventurewere', 'adventurewhat',
#        'adventurewith', 'adventureyou', 'adventuring', 'adventurious',
#        'adventuristic', 'adventurland', 'adventurlandsome', 'adventurous',
#        'adventurousnext', 'adventurure', 'advenure', 'advenureland',
#        'adverage', 'adverse', 'adversely', 'advert', 'advertise',
#        'advertised', 'advertisedits', 'advertisedlines',
#        'advertisedselection', 'advertisement', 'advertisements',
#        'advertisers', 'advertises', 'advertising', 'advertisingdon',
#        'advertized', 'adverts', 'advertsmind', 'advertsnope', 'advertsor',
#        'adverturous', 'adveture', 'advetureland', 'advetures', 'advice',
#        'advicealso', 'advicebring', 'adviced', 'advicego', 'advicei',
#        'adviceif', 'adviceit', 'advicemanage', 'advicemaybe', 'advicemy',
#        'advicerun', 'advices', 'adviceso', 'advicesseptmeber',
#        'advirtised', 'advirtising', 'advisable', 'advisble', 'advise',
#        'advisea', 'adviseable', 'advised', 'advisedisney', 'advisedthe',
#        'advisee', 'advisements', 'adviser', 'advisers', 'advises',
#        'advisesave'], dtype=object)

# %%
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

print(tfidf_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
#       3 print(tfidf_df)
#
# File /lib/python3.12/site-packages/scipy/sparse/_compressed.py:1181, in _cs_matrix.toarray(self, order, out)
#    1179 if out is None and order is None:
#    1180     order = self._swap('cf')[0]
# -> 1181 out = self._process_toarray_args(order, out)
#    1182 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1183     raise ValueError('Output array must be C or F contiguous')
#
# File /lib/python3.12/site-packages/scipy/sparse/_base.py:1301, in _spbase._process_toarray_args(self, order, out)
#    1299     return out
#    1300 else:
# -> 1301     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# ValueError: array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.
